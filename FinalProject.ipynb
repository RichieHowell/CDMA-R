# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import metrics
from sklearn.svm import SVC
import pyper as pr

# %%
#imports the project data as a pandas data frame
projectDF = pd.read_csv('cars93.csv', index_col = 0);
projectDF
# Out:
#    Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 1         Acura        Integra    Small       12.9   15.9       18.8
# 2         Acura         Legend  Midsize       29.2   33.9       38.7
# 3          Audi             90  Compact       25.9   29.1       32.3
# 4          Audi            100  Midsize       30.8   37.7       44.6
# 5           BMW           535i  Midsize       23.7   30.0       36.2
# 6         Buick        Century  Midsize       14.2   15.7       17.3
# 7         Buick        LeSabre    Large       19.9   20.8       21.7
# 8         Buick     Roadmaster    Large       22.6   23.7       24.9
# 9         Buick        Riviera  Midsize       26.3   26.3       26.3
# 10     Cadillac        DeVille    Large       33.0   34.7       36.3
# 11     Cadillac        Seville  Midsize       37.5   40.1       42.7
# 12    Chevrolet       Cavalier  Compact        8.5   13.4       18.3
# 13    Chevrolet        Corsica  Compact       11.4   11.4       11.4
# 14    Chevrolet         Camaro   Sporty       13.4   15.1       16.8
# 15    Chevrolet         Lumina  Midsize       13.4   15.9       18.4
# 16    Chevrolet     Lumina_APV      Van       14.7   16.3       18.0
# 17    Chevrolet          Astro      Van       14.7   16.6       18.6
# 18    Chevrolet        Caprice    Large       18.0   18.8       19.6
# 19    Chevrolet       Corvette   Sporty       34.6   38.0       41.5
# 20     Chrylser       Concorde    Large       18.4   18.4       18.4
# 21     Chrysler        LeBaron  Compact       14.5   15.8       17.1
# 22     Chrysler       Imperial    Large       29.5   29.5       29.5
# 23        Dodge           Colt    Small        7.9    9.2       10.6
# 24        Dodge         Shadow    Small        8.4   11.3       14.2
# 25        Dodge         Spirit  Compact       11.9   13.3       14.7
# 26        Dodge        Caravan      Van       13.6   19.0       24.4
# 27        Dodge        Dynasty  Midsize       14.8   15.6       16.4
# 28        Dodge        Stealth   Sporty       18.5   25.8       33.1
# 29        Eagle         Summit    Small        7.9   12.2       16.5
# 30        Eagle         Vision    Large       17.5   19.3       21.2
# ..          ...            ...      ...        ...    ...        ...
# 64       Nissan         Sentra    Small        8.7   11.8       14.9
# 65       Nissan         Altima  Compact       13.0   15.7       18.3
# 66       Nissan          Quest      Van       16.7   19.1       21.5
# 67       Nissan         Maxima  Midsize       21.0   21.5       22.0
# 68   Oldsmobile        Achieva  Compact       13.0   13.5       14.0
# 69   Oldsmobile  Cutlass_Ciera  Midsize       14.2   16.3       18.4
# 70   Oldsmobile     Silhouette      Van       19.5   19.5       19.5
# 71   Oldsmobile   Eighty-Eight    Large       19.5   20.7       21.9
# 72     Plymouth          Laser   Sporty       11.4   14.4       17.4
# 73      Pontiac         LeMans    Small        8.2    9.0        9.9
# 74      Pontiac        Sunbird  Compact        9.4   11.1       12.8
# 75      Pontiac       Firebird   Sporty       14.0   17.7       21.4
# 76      Pontiac     Grand_Prix  Midsize       15.4   18.5       21.6
# 77      Pontiac     Bonneville    Large       19.4   24.4       29.4
# 78         Saab            900  Compact       20.3   28.7       37.1
# 79       Saturn             SL    Small        9.2   11.1       12.9
# 80       Subaru          Justy    Small        7.3    8.4        9.5
# 81       Subaru         Loyale    Small       10.5   10.9       11.3
# 82       Subaru         Legacy  Compact       16.3   19.5       22.7
# 83       Suzuki          Swift    Small        7.3    8.6       10.0
# 84       Toyota         Tercel    Small        7.8    9.8       11.8
# 85       Toyota         Celica   Sporty       14.2   18.4       22.6
# 86       Toyota          Camry  Midsize       15.2   18.2       21.2
# 87       Toyota         Previa      Van       18.9   22.7       26.6
# 88   Volkswagen            Fox    Small        8.7    9.1        9.5
# 89   Volkswagen        Eurovan      Van       16.6   19.7       22.7
# 90   Volkswagen         Passat  Compact       17.6   20.0       22.4
# 91   Volkswagen        Corrado   Sporty       22.9   23.3       23.7
# 92        Volvo            240  Compact       21.8   22.7       23.5
# 93        Volvo            850  Midsize       24.8   26.7       28.5
#
#     MPG.city  MPG.highway             AirBags DriveTrain    ...      \
# 1         25           31                None      Front    ...
# 2         18           25  Driver & Passenger      Front    ...
# 3         20           26         Driver only      Front    ...
# 4         19           26  Driver & Passenger      Front    ...
# 5         22           30         Driver only       Rear    ...
# 6         22           31         Driver only      Front    ...
# 7         19           28         Driver only      Front    ...
# 8         16           25         Driver only       Rear    ...
# 9         19           27         Driver only      Front    ...
# 10        16           25         Driver only      Front    ...
# 11        16           25  Driver & Passenger      Front    ...
# 12        25           36                None      Front    ...
# 13        25           34         Driver only      Front    ...
# 14        19           28  Driver & Passenger       Rear    ...
# 15        21           29                None      Front    ...
# 16        18           23                None      Front    ...
# 17        15           20                None        4WD    ...
# 18        17           26         Driver only       Rear    ...
# 19        17           25         Driver only       Rear    ...
# 20        20           28  Driver & Passenger      Front    ...
# 21        23           28  Driver & Passenger      Front    ...
# 22        20           26         Driver only      Front    ...
# 23        29           33                None      Front    ...
# 24        23           29         Driver only      Front    ...
# 25        22           27         Driver only      Front    ...
# 26        17           21         Driver only        4WD    ...
# 27        21           27         Driver only      Front    ...
# 28        18           24         Driver only        4WD    ...
# 29        29           33                None      Front    ...
# 30        20           28  Driver & Passenger      Front    ...
# ..       ...          ...                 ...        ...    ...
# 64        29           33         Driver only      Front    ...
# 65        24           30         Driver only      Front    ...
# 66        17           23                None      Front    ...
# 67        21           26         Driver only      Front    ...
# 68        24           31                None      Front    ...
# 69        23           31         Driver only      Front    ...
# 70        18           23                None      Front    ...
# 71        19           28         Driver only      Front    ...
# 72        23           30                None        4WD    ...
# 73        31           41                None      Front    ...
# 74        23           31                None      Front    ...
# 75        19           28  Driver & Passenger       Rear    ...
# 76        19           27                None      Front    ...
# 77        19           28  Driver & Passenger      Front    ...
# 78        20           26         Driver only      Front    ...
# 79        28           38         Driver only      Front    ...
# 80        33           37                None        4WD    ...
# 81        25           30                None        4WD    ...
# 82        23           30         Driver only        4WD    ...
# 83        39           43                None      Front    ...
# 84        32           37         Driver only      Front    ...
# 85        25           32         Driver only      Front    ...
# 86        22           29         Driver only      Front    ...
# 87        18           22         Driver only        4WD    ...
# 88        25           33                None      Front    ...
# 89        17           21                None      Front    ...
# 90        21           30                None      Front    ...
# 91        18           25                None      Front    ...
# 92        21           28         Driver only       Rear    ...
# 93        20           28  Driver & Passenger      Front    ...
#
#    Passengers  Length  Wheelbase  Width  Turn.circle Rear.seat.room  \
# 1           5     177        102     68           37           26.5
# 2           5     195        115     71           38           30.0
# 3           5     180        102     67           37           28.0
# 4           6     193        106     70           37           31.0
# 5           4     186        109     69           39           27.0
# 6           6     189        105     69           41           28.0
# 7           6     200        111     74           42           30.5
# 8           6     216        116     78           45           30.5
# 9           5     198        108     73           41           26.5
# 10          6     206        114     73           43           35.0
# 11          5     204        111     74           44           31.0
# 12          5     182        101     66           38           25.0
# 13          5     184        103     68           39           26.0
# 14          4     193        101     74           43           25.0
# 15          6     198        108     71           40           28.5
# 16          7     178        110     74           44           30.5
# 17          8     194        111     78           42           33.5
# 18          6     214        116     77           42           29.5
# 19          2     179         96     74           43            NaN
# 20          6     203        113     74           40           31.0
# 21          6     183        104     68           41           30.5
# 22          6     203        110     69           44           36.0
# 23          5     174         98     66           32           26.5
# 24          5     172         97     67           38           26.5
# 25          6     181        104     68           39           30.5
# 26          7     175        112     72           42           26.5
# 27          6     192        105     69           42           30.5
# 28          4     180         97     72           40           20.0
# 29          5     174         98     66           36           26.5
# 30          6     202        113     74           40           30.0
# ..        ...     ...        ...    ...          ...            ...
# 64          5     170         96     66           33           26.0
# 65          5     181        103     67           40           28.5
# 66          7     190        112     74           41           27.0
# 67          5     188        104     69           41           28.5
# 68          5     188        103     67           39           28.0
# 69          5     190        105     70           42           28.0
# 70          7     194        110     74           44           30.5
# 71          6     201        111     74           42           31.5
# 72          4     173         97     67           39           24.5
# 73          4     177         99     66           35           25.5
# 74          5     181        101     66           39           25.0
# 75          4     196        101     75           43           25.0
# 76          5     195        108     72           41           28.5
# 77          6     177        111     74           43           30.5
# 78          5     184         99     67           37           26.5
# 79          5     176        102     68           40           26.5
# 80          4     146         90     60           32           23.5
# 81          5     175         97     65           35           27.5
# 82          5     179        102     67           37           27.0
# 83          4     161         93     63           34           27.5
# 84          5     162         94     65           36           24.0
# 85          4     174         99     69           39           23.0
# 86          5     188        103     70           38           28.5
# 87          7     187        113     71           41           35.0
# 88          4     163         93     63           34           26.0
# 89          7     187        115     72           38           34.0
# 90          5     180        103     67           35           31.5
# 91          4     159         97     66           36           26.0
# 92          5     190        104     67           37           29.5
# 93          5     184        105     69           38           30.0
#
#     Luggage.room  Weight   Origin                      Make
# 1             11    2705  non-USA             Acura Integra
# 2             15    3560  non-USA              Acura Legend
# 3             14    3375  non-USA                   Audi 90
# 4             17    3405  non-USA                  Audi 100
# 5             13    3640  non-USA                  BMW 535i
# 6             16    2880      USA             Buick Century
# 7             17    3470      USA             Buick LeSabre
# 8             21    4105      USA          Buick Roadmaster
# 9             14    3495      USA             Buick Riviera
# 10            18    3620      USA          Cadillac DeVille
# 11            14    3935      USA          Cadillac Seville
# 12            13    2490      USA        Chevrolet Cavalier
# 13            14    2785      USA         Chevrolet Corsica
# 14            13    3240      USA          Chevrolet Camaro
# 15            16    3195      USA          Chevrolet Lumina
# 16           NaN    3715      USA      Chevrolet Lumina_APV
# 17           NaN    4025      USA           Chevrolet Astro
# 18            20    3910      USA         Chevrolet Caprice
# 19           NaN    3380      USA        Chevrolet Corvette
# 20            15    3515      USA         Chrylser Concorde
# 21            14    3085      USA          Chrysler LeBaron
# 22            17    3570      USA         Chrysler Imperial
# 23            11    2270      USA                Dodge Colt
# 24            13    2670      USA              Dodge Shadow
# 25            14    2970      USA              Dodge Spirit
# 26           NaN    3705      USA             Dodge Caravan
# 27            16    3080      USA             Dodge Dynasty
# 28            11    3805      USA             Dodge Stealth
# 29            11    2295      USA              Eagle Summit
# 30            15    3490      USA              Eagle Vision
# ..           ...     ...      ...                       ...
# 64            12    2545  non-USA             Nissan Sentra
# 65            14    3050  non-USA             Nissan Altima
# 66           NaN    4100  non-USA              Nissan Quest
# 67            14    3200  non-USA             Nissan Maxima
# 68            14    2910      USA        Oldsmobile Achieva
# 69            16    2890      USA  Oldsmobile Cutlass_Ciera
# 70           NaN    3715      USA     Oldsmobile Silhouette
# 71            17    3470      USA   Oldsmobile Eighty-Eight
# 72             8    2640      USA            Plymouth Laser
# 73            17    2350      USA            Pontiac LeMans
# 74            13    2575      USA           Pontiac Sunbird
# 75            13    3240      USA          Pontiac Firebird
# 76            16    3450      USA        Pontiac Grand_Prix
# 77            18    3495      USA        Pontiac Bonneville
# 78            14    2775  non-USA                  Saab 900
# 79            12    2495      USA                 Saturn SL
# 80            10    2045  non-USA              Subaru Justy
# 81            15    2490  non-USA             Subaru Loyale
# 82            14    3085  non-USA             Subaru Legacy
# 83            10    1965  non-USA              Suzuki Swift
# 84            11    2055  non-USA             Toyota Tercel
# 85            13    2950  non-USA             Toyota Celica
# 86            15    3030  non-USA              Toyota Camry
# 87           NaN    3785  non-USA             Toyota Previa
# 88            10    2240  non-USA            Volkswagen Fox
# 89           NaN    3960  non-USA        Volkswagen Eurovan
# 90            14    2985  non-USA         Volkswagen Passat
# 91            15    2810  non-USA        Volkswagen Corrado
# 92            14    2985  non-USA                 Volvo 240
# 93            15    3245  non-USA                 Volvo 850
#
# [93 rows x 27 columns]

# %%
#turn a nurmerical column into a categorical variable
#first create the bins, i created these based on the min, 25%, 50%, 75% and max values, i used 1 under the min
#since it is not inclusive on the bottom end
bins = [14,18,21,25,46];
#these bins will cut the numerical column into 4 evenly distrubuted categories
projectDF['MPG.city'] = pd.cut(projectDF['MPG.city'],bins);

# %%
#deleting the make column since it is literally just manufacturer + model
projectDF = projectDF.drop('Make', 1)

# %%
#change all rotary values in cylinders to 0
projectDF['Cylinders'].replace('rotary', 0)
# Out:
# 1     4
# 2     6
# 3     6
# 4     6
# 5     4
# 6     4
# 7     6
# 8     6
# 9     6
# 10    8
# 11    8
# 12    4
# 13    4
# 14    6
# 15    4
# ...
# 79    4
# 80    3
# 81    4
# 82    4
# 83    3
# 84    4
# 85    4
# 86    4
# 87    4
# 88    4
# 89    5
# 90    4
# 91    6
# 92    4
# 93    5
# Name: Cylinders, Length: 93, dtype: object

# %%
#fills in all the NaN with 0
projectDF = projectDF.fillna(0);
projectDF
# Out:
#    Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 1         Acura        Integra    Small       12.9   15.9       18.8
# 2         Acura         Legend  Midsize       29.2   33.9       38.7
# 3          Audi             90  Compact       25.9   29.1       32.3
# 4          Audi            100  Midsize       30.8   37.7       44.6
# 5           BMW           535i  Midsize       23.7   30.0       36.2
# 6         Buick        Century  Midsize       14.2   15.7       17.3
# 7         Buick        LeSabre    Large       19.9   20.8       21.7
# 8         Buick     Roadmaster    Large       22.6   23.7       24.9
# 9         Buick        Riviera  Midsize       26.3   26.3       26.3
# 10     Cadillac        DeVille    Large       33.0   34.7       36.3
# 11     Cadillac        Seville  Midsize       37.5   40.1       42.7
# 12    Chevrolet       Cavalier  Compact        8.5   13.4       18.3
# 13    Chevrolet        Corsica  Compact       11.4   11.4       11.4
# 14    Chevrolet         Camaro   Sporty       13.4   15.1       16.8
# 15    Chevrolet         Lumina  Midsize       13.4   15.9       18.4
# 16    Chevrolet     Lumina_APV      Van       14.7   16.3       18.0
# 17    Chevrolet          Astro      Van       14.7   16.6       18.6
# 18    Chevrolet        Caprice    Large       18.0   18.8       19.6
# 19    Chevrolet       Corvette   Sporty       34.6   38.0       41.5
# 20     Chrylser       Concorde    Large       18.4   18.4       18.4
# 21     Chrysler        LeBaron  Compact       14.5   15.8       17.1
# 22     Chrysler       Imperial    Large       29.5   29.5       29.5
# 23        Dodge           Colt    Small        7.9    9.2       10.6
# 24        Dodge         Shadow    Small        8.4   11.3       14.2
# 25        Dodge         Spirit  Compact       11.9   13.3       14.7
# 26        Dodge        Caravan      Van       13.6   19.0       24.4
# 27        Dodge        Dynasty  Midsize       14.8   15.6       16.4
# 28        Dodge        Stealth   Sporty       18.5   25.8       33.1
# 29        Eagle         Summit    Small        7.9   12.2       16.5
# 30        Eagle         Vision    Large       17.5   19.3       21.2
# ..          ...            ...      ...        ...    ...        ...
# 64       Nissan         Sentra    Small        8.7   11.8       14.9
# 65       Nissan         Altima  Compact       13.0   15.7       18.3
# 66       Nissan          Quest      Van       16.7   19.1       21.5
# 67       Nissan         Maxima  Midsize       21.0   21.5       22.0
# 68   Oldsmobile        Achieva  Compact       13.0   13.5       14.0
# 69   Oldsmobile  Cutlass_Ciera  Midsize       14.2   16.3       18.4
# 70   Oldsmobile     Silhouette      Van       19.5   19.5       19.5
# 71   Oldsmobile   Eighty-Eight    Large       19.5   20.7       21.9
# 72     Plymouth          Laser   Sporty       11.4   14.4       17.4
# 73      Pontiac         LeMans    Small        8.2    9.0        9.9
# 74      Pontiac        Sunbird  Compact        9.4   11.1       12.8
# 75      Pontiac       Firebird   Sporty       14.0   17.7       21.4
# 76      Pontiac     Grand_Prix  Midsize       15.4   18.5       21.6
# 77      Pontiac     Bonneville    Large       19.4   24.4       29.4
# 78         Saab            900  Compact       20.3   28.7       37.1
# 79       Saturn             SL    Small        9.2   11.1       12.9
# 80       Subaru          Justy    Small        7.3    8.4        9.5
# 81       Subaru         Loyale    Small       10.5   10.9       11.3
# 82       Subaru         Legacy  Compact       16.3   19.5       22.7
# 83       Suzuki          Swift    Small        7.3    8.6       10.0
# 84       Toyota         Tercel    Small        7.8    9.8       11.8
# 85       Toyota         Celica   Sporty       14.2   18.4       22.6
# 86       Toyota          Camry  Midsize       15.2   18.2       21.2
# 87       Toyota         Previa      Van       18.9   22.7       26.6
# 88   Volkswagen            Fox    Small        8.7    9.1        9.5
# 89   Volkswagen        Eurovan      Van       16.6   19.7       22.7
# 90   Volkswagen         Passat  Compact       17.6   20.0       22.4
# 91   Volkswagen        Corrado   Sporty       22.9   23.3       23.7
# 92        Volvo            240  Compact       21.8   22.7       23.5
# 93        Volvo            850  Midsize       24.8   26.7       28.5
#
#     MPG.city  MPG.highway             AirBags DriveTrain    ...      \
# 1   (21, 25]           31                None      Front    ...
# 2   (14, 18]           25  Driver & Passenger      Front    ...
# 3   (18, 21]           26         Driver only      Front    ...
# 4   (18, 21]           26  Driver & Passenger      Front    ...
# 5   (21, 25]           30         Driver only       Rear    ...
# 6   (21, 25]           31         Driver only      Front    ...
# 7   (18, 21]           28         Driver only      Front    ...
# 8   (14, 18]           25         Driver only       Rear    ...
# 9   (18, 21]           27         Driver only      Front    ...
# 10  (14, 18]           25         Driver only      Front    ...
# 11  (14, 18]           25  Driver & Passenger      Front    ...
# 12  (21, 25]           36                None      Front    ...
# 13  (21, 25]           34         Driver only      Front    ...
# 14  (18, 21]           28  Driver & Passenger       Rear    ...
# 15  (18, 21]           29                None      Front    ...
# 16  (14, 18]           23                None      Front    ...
# 17  (14, 18]           20                None        4WD    ...
# 18  (14, 18]           26         Driver only       Rear    ...
# 19  (14, 18]           25         Driver only       Rear    ...
# 20  (18, 21]           28  Driver & Passenger      Front    ...
# 21  (21, 25]           28  Driver & Passenger      Front    ...
# 22  (18, 21]           26         Driver only      Front    ...
# 23  (25, 46]           33                None      Front    ...
# 24  (21, 25]           29         Driver only      Front    ...
# 25  (21, 25]           27         Driver only      Front    ...
# 26  (14, 18]           21         Driver only        4WD    ...
# 27  (18, 21]           27         Driver only      Front    ...
# 28  (14, 18]           24         Driver only        4WD    ...
# 29  (25, 46]           33                None      Front    ...
# 30  (18, 21]           28  Driver & Passenger      Front    ...
# ..       ...          ...                 ...        ...    ...
# 64  (25, 46]           33         Driver only      Front    ...
# 65  (21, 25]           30         Driver only      Front    ...
# 66  (14, 18]           23                None      Front    ...
# 67  (18, 21]           26         Driver only      Front    ...
# 68  (21, 25]           31                None      Front    ...
# 69  (21, 25]           31         Driver only      Front    ...
# 70  (14, 18]           23                None      Front    ...
# 71  (18, 21]           28         Driver only      Front    ...
# 72  (21, 25]           30                None        4WD    ...
# 73  (25, 46]           41                None      Front    ...
# 74  (21, 25]           31                None      Front    ...
# 75  (18, 21]           28  Driver & Passenger       Rear    ...
# 76  (18, 21]           27                None      Front    ...
# 77  (18, 21]           28  Driver & Passenger      Front    ...
# 78  (18, 21]           26         Driver only      Front    ...
# 79  (25, 46]           38         Driver only      Front    ...
# 80  (25, 46]           37                None        4WD    ...
# 81  (21, 25]           30                None        4WD    ...
# 82  (21, 25]           30         Driver only        4WD    ...
# 83  (25, 46]           43                None      Front    ...
# 84  (25, 46]           37         Driver only      Front    ...
# 85  (21, 25]           32         Driver only      Front    ...
# 86  (21, 25]           29         Driver only      Front    ...
# 87  (14, 18]           22         Driver only        4WD    ...
# 88  (21, 25]           33                None      Front    ...
# 89  (14, 18]           21                None      Front    ...
# 90  (18, 21]           30                None      Front    ...
# 91  (14, 18]           25                None      Front    ...
# 92  (18, 21]           28         Driver only       Rear    ...
# 93  (18, 21]           28  Driver & Passenger      Front    ...
#
#    Fuel.tank.capacity  Passengers  Length  Wheelbase  Width Turn.circle  \
# 1                13.2           5     177        102     68          37
# 2                18.0           5     195        115     71          38
# 3                16.9           5     180        102     67          37
# 4                21.1           6     193        106     70          37
# 5                21.1           4     186        109     69          39
# 6                16.4           6     189        105     69          41
# 7                18.0           6     200        111     74          42
# 8                23.0           6     216        116     78          45
# 9                18.8           5     198        108     73          41
# 10               18.0           6     206        114     73          43
# 11               20.0           5     204        111     74          44
# 12               15.2           5     182        101     66          38
# 13               15.6           5     184        103     68          39
# 14               15.5           4     193        101     74          43
# 15               16.5           6     198        108     71          40
# 16               20.0           7     178        110     74          44
# 17               27.0           8     194        111     78          42
# 18               23.0           6     214        116     77          42
# 19               20.0           2     179         96     74          43
# 20               18.0           6     203        113     74          40
# 21               16.0           6     183        104     68          41
# 22               16.0           6     203        110     69          44
# 23               13.2           5     174         98     66          32
# 24               14.0           5     172         97     67          38
# 25               16.0           6     181        104     68          39
# 26               20.0           7     175        112     72          42
# 27               16.0           6     192        105     69          42
# 28               19.8           4     180         97     72          40
# 29               13.2           5     174         98     66          36
# 30               18.0           6     202        113     74          40
# ..                ...         ...     ...        ...    ...         ...
# 64               13.2           5     170         96     66          33
# 65               15.9           5     181        103     67          40
# 66               20.0           7     190        112     74          41
# 67               18.5           5     188        104     69          41
# 68               15.2           5     188        103     67          39
# 69               16.5           5     190        105     70          42
# 70               20.0           7     194        110     74          44
# 71               18.0           6     201        111     74          42
# 72               15.9           4     173         97     67          39
# 73               13.2           4     177         99     66          35
# 74               15.2           5     181        101     66          39
# 75               15.5           4     196        101     75          43
# 76               16.5           5     195        108     72          41
# 77               18.0           6     177        111     74          43
# 78               18.0           5     184         99     67          37
# 79               12.8           5     176        102     68          40
# 80                9.2           4     146         90     60          32
# 81               15.9           5     175         97     65          35
# 82               15.9           5     179        102     67          37
# 83               10.6           4     161         93     63          34
# 84               11.9           5     162         94     65          36
# 85               15.9           4     174         99     69          39
# 86               18.5           5     188        103     70          38
# 87               19.8           7     187        113     71          41
# 88               12.4           4     163         93     63          34
# 89               21.1           7     187        115     72          38
# 90               18.5           5     180        103     67          35
# 91               18.5           4     159         97     66          36
# 92               15.8           5     190        104     67          37
# 93               19.3           5     184        105     69          38
#
#     Rear.seat.room  Luggage.room  Weight   Origin
# 1             26.5            11    2705  non-USA
# 2             30.0            15    3560  non-USA
# 3             28.0            14    3375  non-USA
# 4             31.0            17    3405  non-USA
# 5             27.0            13    3640  non-USA
# 6             28.0            16    2880      USA
# 7             30.5            17    3470      USA
# 8             30.5            21    4105      USA
# 9             26.5            14    3495      USA
# 10            35.0            18    3620      USA
# 11            31.0            14    3935      USA
# 12            25.0            13    2490      USA
# 13            26.0            14    2785      USA
# 14            25.0            13    3240      USA
# 15            28.5            16    3195      USA
# 16            30.5             0    3715      USA
# 17            33.5             0    4025      USA
# 18            29.5            20    3910      USA
# 19             0.0             0    3380      USA
# 20            31.0            15    3515      USA
# 21            30.5            14    3085      USA
# 22            36.0            17    3570      USA
# 23            26.5            11    2270      USA
# 24            26.5            13    2670      USA
# 25            30.5            14    2970      USA
# 26            26.5             0    3705      USA
# 27            30.5            16    3080      USA
# 28            20.0            11    3805      USA
# 29            26.5            11    2295      USA
# 30            30.0            15    3490      USA
# ..             ...           ...     ...      ...
# 64            26.0            12    2545  non-USA
# 65            28.5            14    3050  non-USA
# 66            27.0             0    4100  non-USA
# 67            28.5            14    3200  non-USA
# 68            28.0            14    2910      USA
# 69            28.0            16    2890      USA
# 70            30.5             0    3715      USA
# 71            31.5            17    3470      USA
# 72            24.5             8    2640      USA
# 73            25.5            17    2350      USA
# 74            25.0            13    2575      USA
# 75            25.0            13    3240      USA
# 76            28.5            16    3450      USA
# 77            30.5            18    3495      USA
# 78            26.5            14    2775  non-USA
# 79            26.5            12    2495      USA
# 80            23.5            10    2045  non-USA
# 81            27.5            15    2490  non-USA
# 82            27.0            14    3085  non-USA
# 83            27.5            10    1965  non-USA
# 84            24.0            11    2055  non-USA
# 85            23.0            13    2950  non-USA
# 86            28.5            15    3030  non-USA
# 87            35.0             0    3785  non-USA
# 88            26.0            10    2240  non-USA
# 89            34.0             0    3960  non-USA
# 90            31.5            14    2985  non-USA
# 91            26.0            15    2810  non-USA
# 92            29.5            14    2985  non-USA
# 93            30.0            15    3245  non-USA
#
# [93 rows x 26 columns]

# %%
#Summary of variables
pd.value_counts(projectDF['MPG.city'])
#for the MPG.city column, there are 25 values in 14 to 17.9999999,  24 values in 18 to 20.99999999, 
#26 values in 21 to 24.99999, and 18 values in 25 to 46
#this means we have the most values in the middle of the data less on the outside
# Out:
# (21, 25]    26
# (14, 18]    25
# (18, 21]    24
# (25, 46]    18
# dtype: int64

# %%
#summary of fuel tank capacity
projectDF['Fuel.tank.capacity'].describe()
#the lowest fuel capactiy is 9.2 gallons, largest is 27 gallons. 
#the data is evenly spread since the mean is 16.6 and the median is 16.4. Most data is + or - 3.3 gallons from the mean
# Out:
# count    93.000000
# mean     16.664516
# std       3.279370
# min       9.200000
# 25%      14.500000
# 50%      16.400000
# 75%      18.800000
# max      27.000000
# dtype: float64

# %%
#summary of the Airbags variable
pd.value_counts(projectDF['AirBags'])
#there are 43 cars with driver only airbags, 34 with no airbag, and 16 with both passenger and driver air bags
#this means that most cars have an airbag, with a vast majority of those only having one on the driver side.
# Out:
# Driver only           43
# None                  34
# Driver & Passenger    16
# dtype: int64

# %%
#creates a histogram of the price variable with 8 bins
hist = projectDF['Price'].hist(bins = 8)
plt.title('histogram of the price variable')
histFig = hist.get_figure()
histFig.savefig('projectHist.png')
plt.clf()
#this is found in a ProjectHist.png in the same folder as this one

# %%
#creates a denisty plot of the min price variable
dens = projectDF['Price'].plot(kind = 'density')
plt.title('density plot of the price variable')
densFig = dens.get_figure()
densFig.savefig('projectDensity.png')
densFig
plt.clf()
#this is found in a ProjectDensity.png in the same folder as this one

# %%
#creates a scatter plot of the price variable and weight variable
scatter = projectDF.plot(kind = 'scatter', x='Price', y='Weight')
plt.title('Scatter plot using the variables Price (x) and Weight(y)')
scatterFig = scatter.get_figure()
scatterFig.savefig('projectScatter.png')
plt.clf()
#this is found in a ProjectScatter.png in the same folder as this one

# %%
projectDF.to_csv("ProjectDF.csv")
# Out:
# count    93.000000
# mean     29.086022
# std       5.331726
# min      20.000000
# 25%      26.000000
# 50%      28.000000
# 75%      31.000000
# max      50.000000
# dtype: float64
